# %%
import tensorflow as tf

# %%
x = tf.placeholder(dtype=tf.float32)

# %%
y = tf.pow((2 * x), 2) +(2 * x) + 1

# %%
init_op = tf.global_variables_initializer()

# %%
sess = tf.Session()

# %%
sess.run(init_op)

# %%
# run computational graph with input
value = sess.run(y, feed_dict={x: 10})

# %%
print(value)
# Out:
# 421.0

# %%
weights = tf.Variable(tf.random_normal(shape=[10]))

# %%
sess.run(tf.global_variables_initializer())
sess.run(weights)
# Out:
# array([ 1.2330906 , -0.35387486, -1.0334253 , -0.40201786,  0.8368627 ,
#        -0.97731525, -0.7144713 ,  1.0511378 , -0.9849595 , -1.7407366 ],
#       dtype=float32)
